# %% [markdown]
# ## $\color{olive}{\text{Danika - Sister 1}}$
#
# I could not have been involved with the murder! I I was updating my online store from 1:45 pm to 3:15 pm. I sat at my desk the whole time, so I was working online when it happened — I couldn’t have done it.
#
# You can check the information log!

# %% [markdown]
# To start our investigation we must read in the information from the information log.
#
# The link to the data log is https://raw.githubusercontent.com/DanikaLipman/JuniorHighDataScienceCamp/refs/heads/main/DataLog.csv
#
# To read in the dataset, use the command read.csv(), with the link in quotations.
#
# Save the data under the name DataLog.

# %%
#Click here to enter your code

# %% [markdown]
# Let's print out the data using the print() command in R

# %%
#Enter your code here
# Out:
#              Timestamp Activity_Type Product_Code Store_Product
# 1  2025-07-14 13:58:00  Image Upload         A048           Art
# 2  2025-07-14 14:08:00  Image Upload         A118           Art
# 3  2025-07-14 13:56:00  Image Upload         A184           Art
# 4  2025-07-14 14:34:00          Edit         A185           Art
# 5  2025-07-14 14:58:00  Image Upload         A200           Art
# 6  2025-07-14 14:21:00          Edit         A202           Art
# 7  2025-07-14 14:40:00          Edit         A209           Art
# 8  2025-07-14 14:14:00  Image Upload         A317           Art
# 9  2025-07-14 15:15:00  Image Upload         A327           Art
# 10 2025-07-14 14:43:00  Image Upload         A431           Art
# 11 2025-07-14 13:45:00          Edit         A459           Art
# 12 2025-07-14 15:06:00  Image Upload         A475           Art
# 13 2025-07-14 13:57:00          Edit         A607           Art
# 14 2025-07-14 14:32:00          Edit         A664           Art
# ...

# %% [markdown]
# In this log, their are 7 columns of data.
#
# - Timestamp
# - Activity_Type
# - Product_Code
# - Store_Product
# - Action_Taken
# - Price_Change
# - Days_Since_Last_Action
#
# We have learned in this camp the difference between numerical and categorical data. Numerical data represents quantities that can be measured or counted, while categorical data represents characteristics or groups. Based on this information, which of the columns are categorical, and which of the columns are numerical?

# %% [markdown]
# Double click here to type your answer.

# %% [markdown]
# Below is the graph of one of the variables. Which variable is represented in the graph?![Price_Change_Hist.png](data:image/png;base64,...)

# %% [markdown]
# Double Click here to type your answer:

# %% [markdown]
# Below is the graph of one of the other variables. Which variable is represented in the graph?
# ![Store_Product_Pie.png](data:image/png;base64,...)

# %% [markdown]
# Double Click here to type your answer:

# %% [markdown]
# To confirm the sisters alibi, let's look to see if there is a gap in the time stamps.
#
# To just extract the timestamps use the print() function, and in the print function type they name of the data, then a dollar sign, and the name of the column.

# %%
#Enter your code here
# Out:
#  [1] "2025-07-14 13:58:00" "2025-07-14 14:08:00" "2025-07-14 13:56:00"
#  [4] "2025-07-14 14:34:00" "2025-07-14 14:58:00" "2025-07-14 14:21:00"
#  [7] "2025-07-14 14:40:00" "2025-07-14 14:14:00" "2025-07-14 15:15:00"
# [10] "2025-07-14 14:43:00" "2025-07-14 13:45:00" "2025-07-14 15:06:00"
# [13] "2025-07-14 13:57:00" "2025-07-14 14:32:00" "2025-07-14 14:20:00"
# [16] "2025-07-14 14:55:00" "2025-07-14 14:29:00" "2025-07-14 14:30:00"
# [19] "2025-07-14 14:27:00" "2025-07-14 13:52:00" "2025-07-14 15:11:00"
# [22] "2025-07-14 13:50:00" "2025-07-14 14:13:00" "2025-07-14 14:17:00"
# [25] "2025-07-14 15:10:00" "2025-07-14 14:46:00" "2025-07-14 14:04:00"
# [28] "2025-07-14 14:49:00" "2025-07-14 15:12:00" "2025-07-14 15:04:00"

# %% [markdown]
# The time stamps are out of order! We can order them by using the sort() function in R!

# %%
#Enter your code here
# Out:
#  [1] "2025-07-14 13:45:00" "2025-07-14 13:50:00" "2025-07-14 13:52:00"
#  [4] "2025-07-14 13:56:00" "2025-07-14 13:57:00" "2025-07-14 13:58:00"
#  [7] "2025-07-14 14:04:00" "2025-07-14 14:08:00" "2025-07-14 14:13:00"
# [10] "2025-07-14 14:14:00" "2025-07-14 14:17:00" "2025-07-14 14:20:00"
# [13] "2025-07-14 14:21:00" "2025-07-14 14:27:00" "2025-07-14 14:29:00"
# [16] "2025-07-14 14:30:00" "2025-07-14 14:32:00" "2025-07-14 14:34:00"
# [19] "2025-07-14 14:40:00" "2025-07-14 14:43:00" "2025-07-14 14:46:00"
# [22] "2025-07-14 14:49:00" "2025-07-14 14:55:00" "2025-07-14 14:58:00"
# [25] "2025-07-14 15:04:00" "2025-07-14 15:06:00" "2025-07-14 15:10:00"
# [28] "2025-07-14 15:11:00" "2025-07-14 15:12:00" "2025-07-14 15:15:00"

# %% [markdown]
# Based on these time stamps, is it possible for the sister to have committed the murder at 3pm?

# %% [markdown]
# Double click here to type your answer.
